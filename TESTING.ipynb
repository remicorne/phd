# %% [markdown]
# HOW MUCH RED PAINT DOES IT TAKE TO BE FUNNIER THAN SOUND?

# %%
from main import *

import pandas as pd

pd.DataFrame().to_excel('test.xlsx')
pd.DataFrame().to_pickle('test.pkl')

# %%
pd.read_pickle('input/cache/TCB2_data_HPLC/compound_and_ratios_df.pkl')
# Out:
#          mouse_id  group_id       value   compound region   treatment  \
# 0               2         1   86.863115        ASP     OF    vehicles
# 0               2         1   86.863115        ASP     OF    vehicles
# 1               5         1   74.158792        ASP     OF    vehicles
# 1               5         1   74.158792        ASP     OF    vehicles
# 2               7         1  124.972338        ASP     OF    vehicles
# ...           ...       ...         ...        ...    ...         ...
# 1198318        70         4   15.717876  5HT/DOPAC      Y  10mg/kgTCB
# 1198319        70         4    5.529584   5HT/5HTP      Y  10mg/kgTCB
# 1198320        70         4    2.925268     5HT/DA      Y  10mg/kgTCB
# 1198321        70         4    1.859482  5HT/5HIAA      Y  10mg/kgTCB
# 1198322        70         4    5.106477    5HT/HVA      Y  10mg/kgTCB
#
#              color          experiment grubbs_outlier  \
# 0            white       dose_response            NaN
# ...

# %%
from dataclasses import dataclass

@dataclass
class Test:
    _test = None
    
    def print(self):
        print(self._test)
        
    def __hash__(self) -> int:
        return 
    
test = Test(_test=2)
# test._test = 1

test.print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 13
#      10     def __hash__(self) -> int:
#      11         return
# ---> 13 test = Test(_test=2)
#      14 # test._test = 1
#      16 test.print()
#
# TypeError: Test.__init__() got an unexpected keyword argument '_test'

# %%
from enum import Enum
from typing import Any
import sys
class Regions:

    AcG = 'Anteriori cingulate cortex'
    
    def __contains__(self: type, obj: object) -> bool:
        return getattr(self, obj)
    
    def __setitem__(self, __name: str, __value: Any) -> None:
        print('lol')
    
print('AcG' in Regions(
))
Regions()['test'] = 5
# Out:
# True
# lol

# %%
from module.core.Project import Project
# import pandas as pd

# pd.read_excel('ALZHEIMERS_HPLC.xlsx')

Project('ALZHEIMERS')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[1], line 6
#       1 from module.core.Project import Project
#       2 # import pandas as pd
#       3
#       4 # pd.read_excel('ALZHEIMERS_HPLC.xlsx')
# ----> 6 Project('ALZHEIMERS')
#
# File <string>:4, in __init__(self, name)
#
# File ~/phd/module/core/Project.py:24, in Project.__post_init__(self)
#      22         print(f"KNOW PROJECTS ARE: {os.listdir(ROOT)}")
#      23         exit(1)
# ---> 24 self.hplc = HPLC(self.name)
#
# File <string>:4, in __init__(self, project)
#
# File ~/phd/module/core/Dataset.py:41, in Dataset.__post_init__(self)
#      39     os.mkdir(self.location)
#      40 if not self.is_pickeled:
# ---> 41     self.initialize()
#
# File ~/phd/module/core/Dataset.py:47, in Dataset.initialize(self)
#      46 def initialize(self):
# ---> 47     self.save(self.generate_data())
# ...
