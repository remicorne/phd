# %%
from module.core.plotters import network_summary


data = network_summary(
    project="TCB2",
    request={
        "datasets": {
            "hplc": {
                # "compound": "neurotransmitters",  # dataset level selector
                # "compound": "neurotransmitters",  # dataset level selector
                # "region": ["OF"],  # dataset level selector
                # "region": "all_regions",
                # "compound": "DA",
                "remove_outliers": "calculated",
            },
            # "behavior": {},  # dataset level selector
        },
        # "selector": {  # Apply to all datasets
        #     "experiment": "agonist_antagonist",  # Stats will take this one into account
        # },
    },
    between={"compound": [["DA", "5HT"], ["NA", "5HT"], ["GLU", "5HT"]]},
    measurement="max_degree",
    custom_params={"size": 15},
)
# Out:
# Processing:   0%|          | 0/18 [00:00<?, ?it/s]
# 0,3mg/kg TCB {'compound': ('DA', '5HT')} insuficient overlapp for [['S1R' 'MR']
#  ['SC' 'MR']
#  ['SJ' 'MR']] pairs
# Inspect with self.corr to adjust {columns} and redo analysis
# Creating networks:   0%|          | 0/18 [00:00<?, ?it/s]
# SAVED /home/remi/phd/PROJECTS/TCB2/All/test

# %%
from module.core.plotters import summary_network_summary


data = summary_network_summary(
    project="TCB2",
    request={
        "datasets": {
            "hplc": {
                # "compound": "neurotransmitters",  # dataset level selector
                # "compound": "neurotransmitters",  # dataset level selector
                # "region": ["OF"],  # dataset level selector
                # "region": "all_regions",
                # "compound": "DA",
                "remove_outliers": "calculated",
            },
            # "behavior": {},  # dataset level selector
        },
        # "selector": {  # Apply to all datasets
        #     "experiment": "agonist_antagonist",  # Stats will take this one into account
        # },
    },
    between={"compound": [["DA", "5HT"], ["NA", "5HT"], ["GLU", "5HT"]]},
    # custom_params={"width": 15, "height": 120},)
)
# Out:
# Processing:   0%|          | 0/18 [00:00<?, ?it/s]
# 0,3mg/kg TCB {'compound': ('DA', '5HT')} insuficient overlapp for [['S1R' 'MR']
#  ['SC' 'MR']
#  ['SJ' 'MR']] pairs
# Inspect with self.corr to adjust {columns} and redo analysis
# Creating networks:   0%|          | 0/18 [00:00<?, ?it/s]
# Skipping measurement, .select() ignores None for practical purpose s, use 'nan' (str) instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       1 from module.core.plotters import summary_network_summary
# ----> 4 data = summary_network_summary(
#       5     project="TCB2",
#       6     request={
#       7         "datasets": {
#       8             "hplc": {
#       9                 # "compound": "neurotransmitters",  # dataset level selector
#      10                 # "compound": "neurotransmitters",  # dataset level selector
#      11                 # "region": ["OF"],  # dataset level selector
#      12                 # "region": "all_regions",
#      13                 # "compound": "DA",
#      14                 "remove_outliers": "calculated",
#      15             },
#      16             # "behavior": {},  # dataset level selector
#      17         },
#      18         # "selector": {  # Apply to all datasets
#      19         #     "experiment": "agonist_antagonist",  # Stats will take this one into account
#      20         # },
#      21     },
#      22     between={"compound": [["DA", "5HT"], ["NA", "5HT"], ["GLU", "5HT"]]},
#      23     # custom_params={"width": 15, "height": 120},)
#      24 )
#
# File ~/phd/module/core/plotters.py:263, in summary_network_summary(project, request, between, measurement, custom_params)
#     259 location = FileSystem.get_location(
#     260     **{"project": project, "experiment": dataset.selector.get("experiment", "All")}
#     261 )
#     262 filepath = os.path.join(location, title)
# --> 263 SummaryHistogram(
#     264     title,
#     265     filepath,
#     266     network_summary_df,
#     267     x,
#     268     hue,
#     269     custom_params=custom_params,
#     270 )
#     271 return network_summary_df
#
# File <string>:11, in __init__(self, title, filepath, data, x, hue, statistic, statistics, custom_params)
#
# File ~/phd/module/core/Figure.py:160, in SummaryHistogram.__post_init__(self)
#     154 self.custom_params["x_order"] = self.custom_params.get(
#     155     "x_order", self.data[self.x].unique()
#     156 )
#     157 self.custom_params["hue_order"] = self.custom_params.get(
#     158     "hue_order", self.data[self.hue].unique()
#     159 )
# --> 160 super().__post_init__()
#
# File ~/phd/module/core/Figure.py:43, in Figure.__post_init__(self)
#      39 def __post_init__(
#      40     self,
#      41 ):
#      42     self.generate_figure()
# ---> 43     self.plot()
#      44     self.save()
#
# File ~/phd/module/core/Figure.py:188, in SummaryHistogram.plot(self)
#     170     sns.barplot(
#     171         data=self.data,
#     172         x=self.x,
#    (...)
#     185         width=self.custom_params.get("bar_width", 0.8),
#     186     )
#     187 if self.custom_params.get("plot_swarm", False):
# --> 188     sns.swarmplot(
#     189         data=self.data,
#     190         x=self.x,
#     191         y="value",
#     192         hue=self.custom_params.get("swarm_hue", self.hue),
#     193         hue_order=self.custom_params.get("hue_order"),
#     194         palette=self.custom_params.get("palette"),
#     195         errorbar=self.custom_params.get("errorbar", "sd"),
#     196         errcolor=self.custom_params.get("errcolor", ".2"),
#     197         capsize=self.custom_params.get("capsize", 0.1),
#     198         alpha=self.custom_params.get("alpha", 0.8),
#     199         order=self.custom_params.get("x_order"),
#     200         errwidth=self.custom_params.get("errwidth", 1),
#     201         width=self.custom_params.get("bar_width", 0.8),
#     202         legend=False if self.custom_params.get("plot_bar") else "auto",
#     203         edgecolor=self.custom_params.get("edgecolor", "k"),
#     204         linewidth=self.custom_params.get("linewidth", 1),
#     205         linestyle=self.custom_params.get("linestyle", "-"),
#     206         dodge=self.custom_params.get("dodge", False),
#     207     )
#     209 self.ax.tick_params(labelsize=20)
#     210 self.ax.set_ylabel(
#     211     self.custom_params.get("ylabel"),
#     212     fontsize=20,
#     213     labelpad=self.custom_params.get("labelpad", 100),
#     214 )
#
# File ~/phd/.venv/lib/python3.10/site-packages/seaborn/categorical.py:2664, in swarmplot(data, x, y, hue, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, native_scale, formatter, legend, warn_thresh, ax, **kwargs)
#    2657     linewidth = size / 10
#    2659 kwargs.update(dict(
#    2660     s=size ** 2,
#    2661     linewidth=linewidth,
#    2662 ))
# -> 2664 p.plot_swarms(
#    2665     dodge=dodge,
#    2666     color=color,
#    2667     edgecolor=edgecolor,
#    2668     warn_thresh=warn_thresh,
#    2669     plot_kws=kwargs,
#    2670 )
#    2672 p._add_axis_labels(ax)
#    2673 p._adjust_cat_axis(ax, axis=p.cat_axis)
#
# File ~/phd/.venv/lib/python3.10/site-packages/seaborn/categorical.py:346, in _CategoricalPlotterNew.plot_swarms(self, dodge, color, edgecolor, warn_thresh, plot_kws)
#     341 for sub_vars, sub_data in self.iter_data(iter_vars,
#     342                                          from_comp_data=True,
#     343                                          allow_empty=True):
#     345     if offsets is not None:
# --> 346         dodge_move = offsets[sub_data["hue"].map(self._hue_map.levels.index)]
#     348     if not sub_data.empty:
#     349         sub_data[self.cat_axis] = sub_data[self.cat_axis] + dodge_move
#
# File ~/phd/.venv/lib/python3.10/site-packages/pandas/core/series.py:4397, in Series.map(self, arg, na_action)
#    4318 def map(
#    4319     self,
#    4320     arg: Callable | Mapping | Series,
#    4321     na_action: Literal["ignore"] | None = None,
#    4322 ) -> Series:
#    4323     """
#    4324     Map values of Series according to an input mapping or function.
#    4325
#    (...)
#    4395     dtype: object
#    4396     """
# -> 4397     new_values = self._map_values(arg, na_action=na_action)
#    4398     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4399         self, method="map"
#    4400     )
#
# File ~/phd/.venv/lib/python3.10/site-packages/pandas/core/base.py:924, in IndexOpsMixin._map_values(self, mapper, na_action)
#     921         raise ValueError(msg)
#     923 # mapper is a function
# --> 924 new_values = map_f(values, mapper)
#     926 return new_values
#
# File ~/phd/.venv/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# ValueError: ('DA', '5HT') is not in list

# %%
from module.core.plotters import histogram


data = histogram(
    project="TCB2",
    request={
        "datasets": {
            "hplc": {
                "compound": "5HT",  # dataset level selector
                # "compound": "neurotransmitters",  # dataset level selector
                "region": ["OF"],  # dataset level selector
                # "region": "all_regions",
                "remove_outliers": "calculated",
            },
            # "behavior": {},  # dataset level selector
        },
        "selector": {  # Apply to all datasets
            "experiment": "agonist_antagonist",  # Stats will take this one into account
        },
    },
    # custom_params={"width": 15, "height": 120},)
)
# Out:
# Calculating statistics:   0%|          | 0/1 [00:00<?, ?it/s]
# SAVED /home/remi/phd/PROJECTS/TCB2/agonist_antagonist/DA in OF

# %%
from module.core.plotters import summary_histogram


data = summary_histogram(
    project="TCB2",
    request={
        "datasets": {
            "hplc": {
                "compound": ["DA", "NA"],  # dataset level selector
                # "compound": "neurotransmitters",  # dataset level selector
                "region": ["OF", "PL"],  # dataset level selector
                # "region": "all_regions",
                "remove_outliers": "calculated",
            },
            # "behavior": {},  # dataset level selector
        },
        "selector": {  # Apply to all datasets
            "experiment": "agonist_antagonist",  # Stats will take this one into account
        },
    },
    # custom_params={"width": 15, "height": 120},)
)
# Out:
# Calculating statistics:   0%|          | 0/4 [00:00<?, ?it/s]
# SAVED /home/remi/phd/PROJECTS/TCB2/agonist_antagonist/DA, NA in OF, PL

# %%
from module.core.plotters import correlogram


data = correlogram(
    project="TCB2",
    request={
        "datasets": {
            "hplc": {
                # "compound": "neurotransmitters",  # dataset level selector
                # "compound": "neurotransmitters",  # dataset level selector
                # "region": ["OF"],  # dataset level selector
                "region": "all_regions",
                # "remove_outliers": "calculated",
            },
            # "behavior": {},  # dataset level selector
        },
        "selector": {  # Apply to all datasets
            "experiment": "agonist_antagonist",  # Stats will take this one into account
        },
    },
    between={"compound": [["DA", "5HT"]]},
    # custom_params={"width": 15, "height": 120},)
)
# Out:
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# SAVED /home/remi/phd/PROJECTS/TCB2/agonist_antagonist/all compounds in all_regions

# %%
from module.core.plotters import network


data = network(
    project="TCB2",
    request={
        "datasets": {
            "hplc": {
                # "compound": "neurotransmitters",  # dataset level selector
                # "compound": "neurotransmitters",  # dataset level selector
                # "region": ["OF"],  # dataset level selector
                "region": "all_regions",
                # "remove_outliers": "calculated",
            },
            # "behavior": {},  # dataset level selector
        },
        "selector": {  # Apply to all datasets
            "experiment": "agonist_antagonist",  # Stats will take this one into account
        },
    },
    between={"compound": [["DA", "5HT"]]},
    # custom_params={"width": 15, "height": 120},)
)
# Out:
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# Creating networks:   0%|          | 0/4 [00:00<?, ?it/s]
# SAVED /home/remi/phd/PROJECTS/TCB2/agonist_antagonist/all compounds in all_regions

# %%
from module.core.plotters import network_degrees


data = network_degrees(
    project="TCB2",
    request={
        "datasets": {
            "hplc": {
                # "compound": "neurotransmitters",  # dataset level selector
                # "compound": "neurotransmitters",  # dataset level selector
                # "region": ["OF"],  # dataset level selector
                "region": "all_regions",
                # "remove_outliers": "calculated",
            },
            # "behavior": {},  # dataset level selector
        },
        "selector": {  # Apply to all datasets
            "experiment": "agonist_antagonist",  # Stats will take this one into account
        },
    },
    between={"compound": [["DA", "5HT"]]},
    # custom_params={"width": 15, "height": 120},)
)
# Out:
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# Creating networks:   0%|          | 0/4 [00:00<?, ?it/s]
# vehicles
# edges = 214, pos = 213, neg = 1 density = 0.26354679802955666, max degree = 33, average degree = 14.758620689655173 unweighted clustering co = 0
# 3mg/kg TCB
# edges = 69, pos = 52, neg = 17 density = 0.08497536945812807, max degree = 14, average degree = 4.758620689655173 unweighted clustering co = 0
# 0,2mg/kg MDL
# edges = 65, pos = 53, neg = 12 density = 0.08004926108374384, max degree = 12, average degree = 4.482758620689655 unweighted clustering co = 0
# TCB2+MDL
# edges = 93, pos = 90, neg = 3 density = 0.1145320197044335, max degree = 15, average degree = 6.413793103448276 unweighted clustering co = 0
# SAVED /home/remi/phd/PROJECTS/TCB2/agonist_antagonist/test
